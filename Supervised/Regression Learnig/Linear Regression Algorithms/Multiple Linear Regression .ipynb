# %% [markdown]
# Multiple Linear Regression is an extension of simple linear Regression  as it takes more then one pedictor variable
# to predict the response variable

# %%
import pandas as pd

# %%
dataset = pd.read_csv("Salary_Data.csv")
dataset.head(3)
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731

# %%
dataset.shape
# Out:
# (30, 3)

# %%
dataset[["YearsExperience","Age"]]= dataset[["YearsExperience","Age"]].astype("int64")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     int64
#  1   Age              30 non-null     int64
#  2   Salary           30 non-null     int64
# dtypes: int64(3)
# memory usage: 852.0 bytes

# %%
dataset.head()
# Out:
#    YearsExperience  Age  Salary
# 0                1   21   39343
# 1                1   21   46205
# 2                1   21   37731
# 3                2   22   43525
# 4                2   22   39891

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x = dataset.iloc[:,:-1]
x.head(5)
# Out:
#    YearsExperience  Age
# 0                1   21
# 1                1   21
# 2                1   21
# 3                2   22
# 4                2   22

# %%
y = dataset["Salary"]

# %%
x.ndim
# Out:
# 2

# %%
dataset.shape
# Out:
# (30, 3)

# %%
from sklearn.model_selection import train_test_split
x_train ,x_test ,y_train ,y_test = train_test_split(x,y ,test_size=0.2,random_state=42)

# %%
 # y_train = y[:6]   # ❌ now it only has 6 samples!

# %%
from sklearn.linear_model import LinearRegression # LinearRegression are apply in multiple linear Regression

# %%
 # lr = LinearRegression()

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
x.shape
# Out:
# (30, 2)

# %%
y.shape
# Out:
# (30,)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# y = m1x1+m2x2+m3x3...+c this formula of multiple linear regression

# %%
lr.score(x_test,y_test)*100
# Out:
# 86.77953535069172

# %%
lr.coef_
# Out:
# array([1860.97857966, 4177.32332093])

# %%
lr.intercept_
# Out:
# np.float64(-47400.77932837143)

# %%
x.columns
# Out:
# Index(['YearsExperience', 'Age'], dtype='object')

# %%
#y_pred = [4177.32332093*Age 4177.32332093*yearExperience -47400.77932837143

# %%
lr.predict(x_test)
# Out:
# array([119731.66744196,  64476.21801347, 101161.39557859,  74691.84323498,
#         54260.59279195,  54260.59279195])
