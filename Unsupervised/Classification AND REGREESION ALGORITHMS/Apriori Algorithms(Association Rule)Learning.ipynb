# %% [markdown]
# # Apriori Algorithm
# Market basket analysis is typically implemented using association rule learning, which is a technique for discovering interesting relationships between variables in a dataset. One of the most popular algorithms for association rule learning is the Apriori algorithm, which is used to identify frequent item sets and generate association rules. These rules are evaluated using measures such as support, confidence, and lift, which are used to determine the strength of the association between items.
#
# For example, consider a dataset of customer purchases from a grocery store. An association rule might be "If a customer buys bread, they are likely to also buy butter."
#
# The Evaluation metric used to evaluate the strength of the association between items are:
#
# # Support:
# It is a measure of the frequency of an itemset in the dataset. Mathematically, it is calculated as follows:
#
# suport(I)=number of transactions containing itemset I / total number of transactions
#
#
# # Confidence:
# It tells us how often the items a and b occur given that a is bought. It is a measure of the reliability of an association rule. Mathematically, it is calculated as follows
#
#   confidence (X → Y) = support(X U Y) / support (X)
#
#
# # Lift:
#
# It is a measure of the strength of an association rule. Mathematically, it is calculated as follows:
#
#   lift(X → y) = confidence (X → Y) / support (Y)
#
# where X and Y are the antecedent and consequent of the rule, respectively

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("Display.max_row",200)

# %%
dataset = pd.read_csv("groceries - groceries.csv")
dataset.head(3)
# Out:
#    Item(s)          Item 1               Item 2     Item 3       Item 4  \
# 0        4    citrus fruit  semi-finished bread  margarine  ready soups
# 1        3  tropical fruit               yogurt     coffee          NaN
# 2        1      whole milk                  NaN        NaN          NaN
#
#   Item 5 Item 6 Item 7 Item 8 Item 9  ... Item 23 Item 24 Item 25 Item 26  \
# 0    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
#
#   Item 27 Item 28 Item 29 Item 30 Item 31 Item 32
# 0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN
#
# [3 rows x 33 columns]

# %%
dataset.isnull().sum()
# Out:
# Item(s)       0
# Item 1        0
# Item 2     2159
# Item 3     3802
# Item 4     5101
# Item 5     6106
# Item 6     6961
# Item 7     7606
# Item 8     8151
# Item 9     8589
# Item 10    8939
# Item 11    9185
# Item 12    9367
# Item 13    9484
# Item 14    9562
# Item 15    9639
# Item 16    9694
# Item 17    9740
# Item 18    9769
# Item 19    9783
# Item 20    9797
# Item 21    9806
# Item 22    9817
# Item 23    9821
# Item 24    9827
# Item 25    9828
# Item 26    9828
# Item 27    9829
# Item 28    9830
# Item 29    9831
# Item 30    9834
# Item 31    9834
# Item 32    9834
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['Item(s)', 'Item 1', 'Item 2', 'Item 3', 'Item 4', 'Item 5', 'Item 6',
#        'Item 7', 'Item 8', 'Item 9', 'Item 10', 'Item 11', 'Item 12',
#        'Item 13', 'Item 14', 'Item 15', 'Item 16', 'Item 17', 'Item 18',
#        'Item 19', 'Item 20', 'Item 21', 'Item 22', 'Item 23', 'Item 24',
#        'Item 25', 'Item 26', 'Item 27', 'Item 28', 'Item 29', 'Item 30',
#        'Item 31', 'Item 32'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (9835, 33)

# %%
# we make list market and customer and drop or delete  nun values 
# in this function all the data put in one columns (all rows are convert in one columns)
market = []
for i in range(0,dataset.shape[0]):
    cus = []
    for j in dataset.columns :
        if type(dataset[j][i])==str: # str are represent string 
            cus.append(dataset[j][i])
    market.append(cus) # customers data are put in market and it will ready list of market without nan values

# %%
# market

# %%
# we get ready list which market data are convert in single list 
l = []
for i in market:
     for j in i:
        l.append(j)

# %%
import collections

# %%
p = collections.Counter(l) # market are counting its mean how many time data are who product are sale or buy

# %%
# p.keys()
# p.values()

# %%
# we get ready a dictionary 
d = {"Name item":p.keys(),"Repeated Data":p.values()}

# %%
# we find data which more repeated 
pd.DataFrame(d).sort_values(by="Repeated Data",ascending=False)
# Out:
#                      Name item  Repeated Data
# 7                   whole milk           2513
# 11            other vegetables           1903
# 17                  rolls/buns           1809
# 31                        soda           1715
# 5                       yogurt           1372
# 24               bottled water           1087
# 42             root vegetables           1072
# 4               tropical fruit           1032
# 52               shopping bags            969
# 50                     sausage            924
# 39                      pastry            875
# 0                 citrus fruit            814
# 19                bottled beer            792
# 35                  newspapers            785
# 49                 canned beer            764
# 8                    pip fruit            744
# 34       fruit/vegetable juice            711
# 60          whipped/sour cream            705
# 51                 brown bread            638
# 65               domestic eggs            624
# 30                 frankfurter            580
# 2                    margarine            576
# 6                       coffee            571
# 58                        pork            567
# 14                      butter            545
# 26                        curd            524
# 29                        beef            516
# 57                     napkins            515
# 25                   chocolate            488
# 78           frozen vegetables            473
# 32                     chicken            422
# 23                 white bread            414
# 9                 cream cheese            390
# 46                     waffles            378
# 45                 salty snack            372
# 13    long life bakery product            368
# 63                     dessert            365
# 33                       sugar            333
# 18                    UHT-milk            329
# 59                     berries            327
# 54              hamburger meat            327
# 56            hygiene articles            324
# 92                      onions            305
# 85         specialty chocolate            299
# 47                       candy            294
# 90                frozen meals            279
# 67             misc. beverages            279
# 74                         oil            276
# 38                 butter milk            275
# 37               specialty bar            269
# 70                         ham            256
# 53                   beverages            256
# 123                       meat            254
# 77                   ice cream            246
# 68                 hard cheese            241
# 97               sliced cheese            241
# 69                    cat food            229
# 62                      grapes            220
# 75                 chewing gum            207
# 82              red/blush wine            189
# 41                   detergent            189
# 94                  white wine            187
# 73          pickled vegetables            176
# 1          semi-finished bread            174
# 72               baking powder            174
# 28                      dishes            173
# 27                       flour            171
# 21               potted plants            170
# 105                soft cheese            168
# 40            processed cheese            163
# 93                       herbs            160
# 98                       pasta            148
# 79                 canned fish            148
# 80           seasonal products            140
# 109                   cake bar            130
# 36   packaged fruit/vegetables            128
# 125                    mustard            118
# 117                frozen fish            115
# 100            cling film/bags            112
# 66               spread cheese            110
# 129                     liquor            109
# 43              frozen dessert            106
# 91           canned vegetables            106
# 89                        salt            106
# 121               dish cleaner            103
# 87              flower (seeds)            102
# 139              roll products            101
# 12              condensed milk            101
# 130                   pet care             93
# 96                  photo/film             91
# 140                 mayonnaise             90
# 76       chocolate marshmallow             89
# 44               sweet spreads             89
# 86                     candles             88
# 115                   dog food             84
# 112           specialty cheese             84
# 83      frozen potato products             83
# 126     house keeping products             82
# 71                      turkey             80
# 104      Instant food products             79
# 20          liquor (appetizer)             78
# 15                        rice             75
# 138             instant coffee             73
# 108                    popcorn             71
# 64                    zwieback             68
# 131                      soups             67
# 113          finished products             64
# 135                    vinegar             64
# 120   female sanitary products             60
# 147             kitchen towels             59
# 107                dental care             57
# 22                     cereals             56
# 88              sparkling wine             55
# 134                     sauces             54
# 99                    softener             54
# 151                        jam             53
# 55                      spices             51
# 143                 liver loaf             50
# 119                    cleaner             50
# 81                 curd cheese             50
# 102             male cosmetics             45
# 132                        rum             44
# 150                    ketchup             42
# 10                meat spreads             42
# 95                      brandy             41
# 149                light bulbs             41
# 124                        tea             38
# 84               specialty fat             36
# 16            abrasive cleaner             35
# 127                  skin care             35
# 153                nuts/prunes             33
# 61            artif. sweetener             32
# 103               canned fruit             32
# 142                      syrup             32
# 146                  nut snack             31
# 110             snack products             30
# 101                       fish             29
# 128            potato products             28
# 48            bathroom cleaner             27
# 122                   cookware             27
# 136                       soap             26
# 165          cooking chocolate             25
# 160             pudding powder             23
# 161                    tidbits             23
# 155            organic sausage             22
# 114               cocoa drinks             22
# 116                   prosecco             20
# 111     flower soil/fertilizer             19
# 3                  ready soups             18
# 158       specialty vegetables             17
# 145           organic products             16
# 106                      honey             15
# 152                decalcifier             15
# 156                      cream             13
# 163              frozen fruits             12
# 137                 hair spray             11
# 141            rubbing alcohol             10
# 154                    liqueur              9
# 118            make up remover              8
# 133             salad dressing              8
# 162                     whisky              8
# 157             toilet cleaner              7
# 144             baby cosmetics              6
# 148             frozen chicken              6
# 164                       bags              4
# 167            kitchen utensil              4
# 168      preservation products              2
# 159                  baby food              1
# 166       sound storage medium              1

# %%
# we get ready matric of product by mlxtend how many time product are repeating

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr = TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
df = pd.DataFrame(tr.transform(market),columns=tr.columns_)

# %%
# df

# %%
from mlxtend.frequent_patterns import apriori

# %%
apriori(df,min_support=0.07,use_colnames=True,max_len=3).sort_values(by=["support"]) 
# (whole milk, other vegetables) this product are more repeated    and sort_values function are use for display more values
# Out:
#      support                        itemsets
# 0   0.080529                  (bottled beer)
# 1   0.110524                 (bottled water)
# 2   0.077682                   (canned beer)
# 3   0.082766                  (citrus fruit)
# 4   0.072293         (fruit/vegetable juice)
# 5   0.079817                    (newspapers)
# 6   0.193493              (other vegetables)
# 7   0.088968                        (pastry)
# 8   0.075648                     (pip fruit)
# 9   0.183935                    (rolls/buns)
# 10  0.108998               (root vegetables)
# 11  0.093950                       (sausage)
# 12  0.098526                 (shopping bags)
# 13  0.174377                          (soda)
# 14  0.104931                (tropical fruit)
# 15  0.071683            (whipped/sour cream)
# 16  0.255516                    (whole milk)
# 17  0.139502                        (yogurt)
# 18  0.074835  (whole milk, other vegetables)
